# %%
import pandas as pd
from dt_analysis import DecisionTreeC_Analysis
from xgb_analysis import XGBC_Analysis
from mlpc_analysis import MLPC_Analysis
from svm_analysis import SVMC_Analysis
from knn_analysis import KNNC_Analysis

# %%
df_student = pd.read_csv("./../../data/cleaned_student_data.csv")
df_student.index.name = 'Student Dataset'
df_housing = pd.read_csv("./../../data/cleaned_housing_data_preped_class_nozero.csv")
df_housing.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'OBJECTID', '2018-07-22T18:01:43.000Z'], axis=1, inplace=True)
df_housing.drop(columns=[i for i in df_housing.columns if i.find('Police') != -1], axis=1, inplace=True)
df_housing.index.name = 'Housing Dataset'

df_housing = df_housing.sample(30000, random_state=7308)

datasets = [df_housing]
targets = ['class']

# %%
for dataset, target in zip(datasets, targets):
    analysis = DecisionTreeC_Analysis(dataset=dataset, target=target, save=True)
    analysis.general_analysis()
    r1 = analysis.depth_analysis(range_=range(2,30))
    r2 = analysis.max_node_analysis(range_ = np.linspace(2, 1000, 50, dtype=int))
    
    analysis = XGBC_Analysis(dataset=dataset, target=target, save=True)
    analysis.general_analysis()
    r3 = analysis.depth_analysis(range_=range(2,30))
    r4 = analysis.n_estimator_analysis()
    r5 = analysis.lr_analysis()
    
    analysis = SVMC_Analysis(dataset=dataset, target=target, save=True)
    analysis.general_analysis()
    r6 = analysis.kernel_analysis()
    r7 = analysis.penalty_analysis()
    
    analysis = MLPC_Analysis(dataset=dataset, target=target, save=True)
    analysis.general_analysis()
    r8 = analysis.hidden_layer_analysis()
    r9 = analysis.activation_analysis()
    
    analysis = KNNC_Analysis(dataset=dataset, target=target, save=True)
    analysis.general_analysis()
    r10 = analysis.n_neighbors_analysis()
# Out:
# ######
# Decision Tree Classifier:
# Default Baseline values (no max depth or max leaf nodes)
# ~~~~~~
# Execution time metrics
# Training time input dim of (24000, 286) : 0.8675 (+/- 0.0603)
# Testing time input dim of (6000, 286): 0.0438 (+/- 0.0034)
# ~~~~~~
#
# Split on Gini Importance:
# 10 Fold Cross Validation Accuracy: 0.7356 (+/- 0.0110)
# Training Accuracy: 0.9999583333333333
# Training F1: 0.9999583333312337
# Testing Accuracy: 0.732
# Testing F1: 0.7325657757610713
# ~~~~~~
#
# Split on Entropy Gain:
# 10 Fold Cross Validation Accuracy: 0.7388 (+/- 0.0191)
# Training Accuracy: 0.9999583333333333
# Training F1: 0.9999583333312337
# Testing Accuracy: 0.7365
# Testing F1: 0.738341028825476
# ~~~~~~
#
#
# Testing different tree depths
# Testing different maximum leaf nodes
# ######
# eXtreme Gradient Boosted Decision Tree Classifier:
# Default baseline values
# ~~~~~~
# Execution time metrics
# Training time: 68.4875 (+/- 0.3809)
# Testing time: 0.5855 (+/- 0.0184)
# ~~~~~~
# 10 Fold Cross Validation Accuracy: 0.7912 (+/- 0.0087)
# Training Accuracy: 0.8047916666666667
# Training F1: 0.8048082048769215
# Testing Accuracy: 0.7856666666666666
# Testing F1: 0.7862431112820565
# ~~~~~~
#
#
# Testing different tree depths.
# Testing different amounts of trees.
# Testing different learning rates.
# ######
# Support Vector Machine Classifier:
# Default baseline values
# ~~~~~~
# Execution time metrics
# Training time: 164.7695 (+/- 0.6055)
# Testing time: 125.9789 (+/- 0.1756)
# ~~~~~~
# 10 Fold Cross Validation Accuracy: 0.7546 (+/- 0.0089)
# Training Accuracy: 0.8290416666666667
# Training F1: 0.829715742685688
# Testing Accuracy: 0.7501666666666666
# Testing F1: 0.7517056432074467
# ~~~~~~
#
#
# Testing Different Kernel Functions with 10 Fold X-Val
#
# Testing Different Penalty Values with 10 Fold X-Val
#
# ######
# Multilayer Perceptron Classifier:
# Default Baseline values
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4818a7b2e6f2> in <module>
#      17
#      18     analysis = MLPC_Analysis(dataset=dataset, target=target, save=True)
# ---> 19     analysis.general_analysis()
#      20     r8 = analysis.hidden_layer_analysis()
#      21     r9 = analysis.activation_analysis()
#
# ~/Documents/OMSCS/CS7641/assignments/assignment_1/mlpc_analysis.py in general_analysis(self)
#      38         # plot_learning_curves(self.data, self.target, clf,
#      39         #                    plt_title='{} MLP Learning Curves'.format(self.data.index.name))
# ---> 40         plot_learning_curve(clf, '{} SVM Learning Curve'.format(self.data.index.name), self.data, self.target, cv=5)
#      41
#      42         print("~~~~~~")
#
# ~/Documents/OMSCS/CS7641/assignments/assignment_1/ancillary.py in plot_learning_curve(estimator, title, dataset, target, ylim, cv, n_jobs, train_sizes)
#     121     plt.xlabel("Training size precentage")
#     122     plt.ylabel("Score")
# --> 123     train_sizes_, train_scores, test_scores = learning_curve(
#     124         estimator, X, y, cv=cv, n_jobs=n_jobs, train_sizes=train_sizes)
#     125     train_scores_mean = np.mean(train_scores, axis=1)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/model_selection/_validation.py in learning_curve(estimator, X, y, groups, train_sizes, cv, scoring, exploit_incremental_learning, n_jobs, pre_dispatch, verbose, shuffle, random_state, error_score)
#    1244             parameters=None, fit_params=None, return_train_score=True,
#    1245             error_score=error_score)
# -> 1246             for train, test in train_test_proportions)
#    1247         out = np.array(out)
#    1248         n_cv_folds = out.shape[0] // n_unique_ticks
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in __call__(self, iterable)
#     928
#     929             with self._backend.retrieval_context():
# --> 930                 self.retrieve()
#     931             # Make sure that we get a last message telling us we are done
#     932             elapsed_time = time.time() - self._start_time
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/externals/joblib/parallel.py in retrieve(self)
#     831             try:
#     832                 if getattr(self._backend, 'supports_timeout', False):
# --> 833                     self._output.extend(job.get(timeout=self.timeout))
#     834                 else:
#     835                     self._output.extend(job.get())
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/externals/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     519         AsyncResults.get from multiprocessing."""
#     520         try:
# --> 521             return future.result(timeout=timeout)
#     522         except LokyTimeoutError:
#     523             raise TimeoutError()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/concurrent/futures/_base.py in result(self, timeout)
#     425                 return self.__get_result()
#     426
# --> 427             self._condition.wait(timeout)
#     428
#     429             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/threading.py in wait(self, timeout)
#     293         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     294             if timeout is None:
# --> 295                 waiter.acquire()
#     296                 gotit = True
#     297             else:
#
# KeyboardInterrupt:
